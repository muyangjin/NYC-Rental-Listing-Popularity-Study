# %% [markdown]
# ## Data Import

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("."))

# Any results you write to the current directory are saved as output.
# Out:
# ['names.txt', '.DS_Store', 'CaseStudy_Churn_Analysis_2016.ipynb', 'Untitled.ipynb', 'en.openfoodfacts.org.products.csv', 'test.json', '07 Project.ipynb', 'DS_GA_1007_Final_Project.pdf', 'train.json', '.ipynb_checkpoints', 'kernel.ipynb', 'sample_submission.csv']

# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
import warnings
warnings.filterwarnings('ignore')

# %%
df_original = pd.read_json('train.json')
df = df_original.copy()
df.index = df['listing_id']
df = df.drop('listing_id',1)
df['interest_level'] = df['interest_level'].map({'medium':0, 'low' : -1, 'high': 1})
df.head()
# Out:
#             bathrooms  bedrooms                       building_id  \
# listing_id
# 7211212           1.5         3  53a5b119ba8f7b61d4e010512e0dfc85
# 7150865           1.0         2  c5c8a357cba207596b04d1afd1e4f130
# 6887163           1.0         1  c3ba40552e2120b0acfc3cb5730bb2aa
# 6888711           1.0         1  28d9ad350afeaab8027513a3e52ac8d5
# 6934781           1.0         4                                 0
#
#                         created  \
# listing_id
# 7211212     2016-06-24 07:54:24
# 7150865     2016-06-12 12:19:27
# 6887163     2016-04-17 03:26:41
# 6888711     2016-04-18 02:22:02
# 6934781     2016-04-28 01:32:41
#
#                                                   description  \
# listing_id
# 7211212     A Brand New 3 Bedroom 1.5 bath ApartmentEnjoy ...
# 7150865
# 6887163     Top Top West Village location, beautiful Pre-w...
# 6888711     Building Amenities - Garage - Garden - fitness...
# 6934781     Beautifully renovated 3 bedroom flex 4 bedroom...
#
#                 display_address  \
# listing_id
# 7211212     Metropolitan Avenue
# 7150865         Columbus Avenue
# 6887163             W 13 Street
# 6888711        East 49th Street
# 6934781       West 143rd Street
#
#                                                      features  latitude  \
# listing_id
# 7211212                                                    []   40.7145
# 7150865     [Doorman, Elevator, Fitness Center, Cats Allow...   40.7947
# 6887163     [Laundry In Building, Dishwasher, Hardwood Flo...   40.7388
# 6888711                             [Hardwood Floors, No Fee]   40.7539
# 6934781                                             [Pre-War]   40.8241
#
#             longitude                        manager_id  \
# listing_id
# 7211212      -73.9425  5ba989232d0489da1b5f2c45f6688adc
# 7150865      -73.9667  7533621a882f71e25173b27e3139d83d
# 6887163      -74.0018  d9039c43983f6e564b1482b273bd7b01
# 6888711      -73.9677  1067e078446a7897d2da493d2f741316
# 6934781      -73.9493  98e13ad4b495b9613cef886d79a6291f
#
#                                                        photos  price  \
# listing_id
# 7211212     [https://photos.renthop.com/2/7211212_1ed4542e...   3000
# 7150865     [https://photos.renthop.com/2/7150865_be3306c5...   5465
# 6887163     [https://photos.renthop.com/2/6887163_de85c427...   2850
# 6888711     [https://photos.renthop.com/2/6888711_6e660cee...   3275
# 6934781     [https://photos.renthop.com/2/6934781_1fa4b41a...   3350
#
#                      street_address  interest_level
# listing_id
# 7211212     792 Metropolitan Avenue               0
# 7150865         808 Columbus Avenue              -1
# 6887163             241 W 13 Street               1
# 6888711        333 East 49th Street              -1
# 6934781       500 West 143rd Street              -1

# %% [markdown]
# ## Data Cleaning
# -  __Drop: created, display_address, street_address, latitude, longtitude__

# %%
df = df.drop(['created', 'display_address', 'street_address', 'latitude', 'longitude'], 1)
df.head()
# Out:
#             bathrooms  bedrooms                       building_id  \
# listing_id
# 7211212           1.5         3  53a5b119ba8f7b61d4e010512e0dfc85
# 7150865           1.0         2  c5c8a357cba207596b04d1afd1e4f130
# 6887163           1.0         1  c3ba40552e2120b0acfc3cb5730bb2aa
# 6888711           1.0         1  28d9ad350afeaab8027513a3e52ac8d5
# 6934781           1.0         4                                 0
#
#                                                   description  \
# listing_id
# 7211212     A Brand New 3 Bedroom 1.5 bath ApartmentEnjoy ...
# 7150865
# 6887163     Top Top West Village location, beautiful Pre-w...
# 6888711     Building Amenities - Garage - Garden - fitness...
# 6934781     Beautifully renovated 3 bedroom flex 4 bedroom...
#
#                                                      features  \
# listing_id
# 7211212                                                    []
# 7150865     [Doorman, Elevator, Fitness Center, Cats Allow...
# 6887163     [Laundry In Building, Dishwasher, Hardwood Flo...
# 6888711                             [Hardwood Floors, No Fee]
# 6934781                                             [Pre-War]
#
#                                   manager_id  \
# listing_id
# 7211212     5ba989232d0489da1b5f2c45f6688adc
# 7150865     7533621a882f71e25173b27e3139d83d
# 6887163     d9039c43983f6e564b1482b273bd7b01
# 6888711     1067e078446a7897d2da493d2f741316
# 6934781     98e13ad4b495b9613cef886d79a6291f
#
#                                                        photos  price  \
# listing_id
# 7211212     [https://photos.renthop.com/2/7211212_1ed4542e...   3000
# 7150865     [https://photos.renthop.com/2/7150865_be3306c5...   5465
# 6887163     [https://photos.renthop.com/2/6887163_de85c427...   2850
# 6888711     [https://photos.renthop.com/2/6888711_6e660cee...   3275
# 6934781     [https://photos.renthop.com/2/6934781_1fa4b41a...   3350
#
#             interest_level
# listing_id
# 7211212                  0
# 7150865                 -1
# 6887163                  1
# 6888711                 -1
# 6934781                 -1

# %% [markdown]
# - __latitude, longtitude, price, bedroom, description__

# %%
# def lat_long(l):
#     '''For latitude and longtitude, delete outlier and normalize.'''
#     l = l.loc[l['latitude']<40.95, :]
#     l = l.loc[l['latitude']>40.55, :]
#     l = l.loc[l['longitude']<-73.80, :]
#     l = l.loc[l['longitude']>-74.05, :]
#     l['latitude'] = preprocessing.scale(l['latitude'])
#     l['longitude'] = preprocessing.scale(l['longitude'])
#     return l

def price_beds(df):
    '''For bedroom and price, build price/bedrooms and drop the two columns.'''
    beds = np.array(df['bedrooms'])
    beds += 1
    price = np.array(df['price'])
    p_b = price/beds
    df['price/bedrooms'] = p_b
    df['price/bedrooms'] = preprocessing.scale(df['price/bedrooms'])
    df = df.drop('bedrooms', 1)
    df = df.drop('price', 1)
    return df

def des_length(df):
    '''For description, change the column into the length of the description.'''
    des_len = []
    for i in df['description']:
        des_len.append(len(i))
    df['des_length'] = des_len
    df['des_length'] = preprocessing.scale(df['des_length'])
    df = df.drop('description', 1)
    return df

# %%
# df = lat_long(df)
df = des_length(df)
df = price_beds(df)
df.head()
# Out:
#             bathrooms                       building_id  \
# listing_id
# 7211212           1.5  53a5b119ba8f7b61d4e010512e0dfc85
# 7150865           1.0  c5c8a357cba207596b04d1afd1e4f130
# 6887163           1.0  c3ba40552e2120b0acfc3cb5730bb2aa
# 6888711           1.0  28d9ad350afeaab8027513a3e52ac8d5
# 6934781           1.0                                 0
#
#                                                      features  \
# listing_id
# 7211212                                                    []
# 7150865     [Doorman, Elevator, Fitness Center, Cats Allow...
# 6887163     [Laundry In Building, Dishwasher, Hardwood Flo...
# 6888711                             [Hardwood Floors, No Fee]
# 6934781                                             [Pre-War]
#
#                                   manager_id  \
# listing_id
# 7211212     5ba989232d0489da1b5f2c45f6688adc
# 7150865     7533621a882f71e25173b27e3139d83d
# 6887163     d9039c43983f6e564b1482b273bd7b01
# 6888711     1067e078446a7897d2da493d2f741316
# 6934781     98e13ad4b495b9613cef886d79a6291f
#
#                                                        photos  interest_level  \
# listing_id
# 7211212     [https://photos.renthop.com/2/7211212_1ed4542e...               0
# 7150865     [https://photos.renthop.com/2/7150865_be3306c5...              -1
# 6887163     [https://photos.renthop.com/2/6887163_de85c427...               1
# 6888711     [https://photos.renthop.com/2/6888711_6e660cee...              -1
# 6934781     [https://photos.renthop.com/2/6934781_1fa4b41a...              -1
#
#             des_length  price/bedrooms
# listing_id
# 7211212      -0.035508       -0.116088
# 7150865      -1.509129        0.020990
# 6887163       0.226187       -0.029748
# 6888711      -0.279418       -0.002567
# 6934781      -0.312447       -0.126321

# %% [markdown]
# - __photos__

# %%
# fig_num = []
# for i in range(len(df)):
#     c = len(df_train.iloc[,])
#     fig_num.append(c)
df['Photo Number'] = df['photos'].apply(len)
df = df.drop('photos',1)
df.head()
# Out:
#             bathrooms                       building_id  \
# listing_id
# 7211212           1.5  53a5b119ba8f7b61d4e010512e0dfc85
# 7150865           1.0  c5c8a357cba207596b04d1afd1e4f130
# 6887163           1.0  c3ba40552e2120b0acfc3cb5730bb2aa
# 6888711           1.0  28d9ad350afeaab8027513a3e52ac8d5
# 6934781           1.0                                 0
#
#                                                      features  \
# listing_id
# 7211212                                                    []
# 7150865     [Doorman, Elevator, Fitness Center, Cats Allow...
# 6887163     [Laundry In Building, Dishwasher, Hardwood Flo...
# 6888711                             [Hardwood Floors, No Fee]
# 6934781                                             [Pre-War]
#
#                                   manager_id  interest_level  des_length  \
# listing_id
# 7211212     5ba989232d0489da1b5f2c45f6688adc               0   -0.035508
# 7150865     7533621a882f71e25173b27e3139d83d              -1   -1.509129
# 6887163     d9039c43983f6e564b1482b273bd7b01               1    0.226187
# 6888711     1067e078446a7897d2da493d2f741316              -1   -0.279418
# 6934781     98e13ad4b495b9613cef886d79a6291f              -1   -0.312447
#
#             price/bedrooms  Photo Number
# listing_id
# 7211212          -0.116088             5
# 7150865           0.020990            11
# 6887163          -0.029748             8
# 6888711          -0.002567             3
# 6934781          -0.126321             3

# %% [markdown]
# - __features__

# %%
import string
table = str.maketrans('','',string.punctuation)
#Building a cleaned list and a merged cleaned string for the features column of each instance
df['Features List'] = df['features'].apply(lambda y : list(map(lambda x: x.upper().translate(table), y)))
df['Features String'] = df['Features List'].apply(' '.join)
df = df.drop('features',1)
df.head()
# Out:
#             bathrooms                       building_id  \
# listing_id
# 7211212           1.5  53a5b119ba8f7b61d4e010512e0dfc85
# 7150865           1.0  c5c8a357cba207596b04d1afd1e4f130
# 6887163           1.0  c3ba40552e2120b0acfc3cb5730bb2aa
# 6888711           1.0  28d9ad350afeaab8027513a3e52ac8d5
# 6934781           1.0                                 0
#
#                                   manager_id  interest_level  des_length  \
# listing_id
# 7211212     5ba989232d0489da1b5f2c45f6688adc               0   -0.035508
# 7150865     7533621a882f71e25173b27e3139d83d              -1   -1.509129
# 6887163     d9039c43983f6e564b1482b273bd7b01               1    0.226187
# 6888711     1067e078446a7897d2da493d2f741316              -1   -0.279418
# 6934781     98e13ad4b495b9613cef886d79a6291f              -1   -0.312447
#
#             price/bedrooms  Photo Number  \
# listing_id
# 7211212          -0.116088             5
# 7150865           0.020990            11
# 6887163          -0.029748             8
# 6888711          -0.002567             3
# 6934781          -0.126321             3
#
#                                                 Features List  \
# listing_id
# 7211212                                                    []
# 7150865     [DOORMAN, ELEVATOR, FITNESS CENTER, CATS ALLOW...
# 6887163     [LAUNDRY IN BUILDING, DISHWASHER, HARDWOOD FLO...
# 6888711                             [HARDWOOD FLOORS, NO FEE]
# 6934781                                              [PREWAR]
#
#                                               Features String
# listing_id
# 7211212
# 7150865     DOORMAN ELEVATOR FITNESS CENTER CATS ALLOWED D...
# 6887163     LAUNDRY IN BUILDING DISHWASHER HARDWOOD FLOORS...
# 6888711                                HARDWOOD FLOORS NO FEE
# 6934781                                                PREWAR

# %%
#Build 24 feature columns containing 0 which occur most frequently. 
feature = []
biglist = []
for i in range(len(df)):
    biglist += df.iloc[i]['Features List']
    for w in df.iloc[i]['Features List']:
        if w not in feature:
            feature.append(w)
bigdic = {i : biglist.count(i) for i in feature}

df_feature_count = pd.DataFrame(bigdic, index = ['Count']).T
add_ones = list(df_feature_count.sort_values(by = ['Count'],ascending = False)[:24].index)
for i in add_ones:
    df['f_' + '_'.join(i.split(' '))] = 0

# %%
#Change zeros into binary
for i in add_ones:
    onelist = []
    for w in range(len(df)):
        onelist.append(i in df.iloc[w]['Features String'])
    print('f_' + '_'.join(i.split(' ')))
    df['f_' + '_'.join(i.split(' '))] = onelist
# Out:
# f_ELEVATOR
# f_HARDWOOD_FLOORS
# f_CATS_ALLOWED
# f_DOGS_ALLOWED
# f_DOORMAN
# f_DISHWASHER
# f_LAUNDRY_IN_BUILDING
# f_NO_FEE
# f_FITNESS_CENTER
# f_PREWAR
# f_LAUNDRY_IN_UNIT
# f_ROOF_DECK
# f_OUTDOOR_SPACE
# f_DINING_ROOM
# f_HIGH_SPEED_INTERNET
# f_BALCONY
# f_SWIMMING_POOL
# f_NEW_CONSTRUCTION
# f_TERRACE
# f_EXCLUSIVE
# f_LOFT
# f_GARDENPATIO
# f_WHEELCHAIR_ACCESS
# f_COMMON_OUTDOOR_SPACE

# %%
df = df.drop('Features List', 1)
df = df.drop('Features String', 1)
all_features = df.columns.tolist()
all_features.remove('interest_level')
all_features = all_features + ['interest_level']
df = df[all_features]
df.head()
# Out:
#             bathrooms                       building_id  \
# listing_id
# 7211212           1.5  53a5b119ba8f7b61d4e010512e0dfc85
# 7150865           1.0  c5c8a357cba207596b04d1afd1e4f130
# 6887163           1.0  c3ba40552e2120b0acfc3cb5730bb2aa
# 6888711           1.0  28d9ad350afeaab8027513a3e52ac8d5
# 6934781           1.0                                 0
#
#                                   manager_id  des_length  price/bedrooms  \
# listing_id
# 7211212     5ba989232d0489da1b5f2c45f6688adc   -0.035508       -0.116088
# 7150865     7533621a882f71e25173b27e3139d83d   -1.509129        0.020990
# 6887163     d9039c43983f6e564b1482b273bd7b01    0.226187       -0.029748
# 6888711     1067e078446a7897d2da493d2f741316   -0.279418       -0.002567
# 6934781     98e13ad4b495b9613cef886d79a6291f   -0.312447       -0.126321
#
#             Photo Number  f_ELEVATOR  f_HARDWOOD_FLOORS  f_CATS_ALLOWED  \
# listing_id
# 7211212                5       False              False           False
# 7150865               11        True              False            True
# 6887163                8       False               True           False
# 6888711                3       False               True           False
# 6934781                3       False              False           False
#
#             f_DOGS_ALLOWED  ...  f_BALCONY  f_SWIMMING_POOL  \
# listing_id                  ...
# 7211212              False  ...      False            False
# 7150865               True  ...      False            False
# 6887163              False  ...      False            False
# 6888711              False  ...      False            False
# 6934781              False  ...      False            False
#
#             f_NEW_CONSTRUCTION  f_TERRACE  f_EXCLUSIVE  f_LOFT  f_GARDENPATIO  \
# listing_id
# 7211212                  False      False        False   False          False
# 7150865                  False      False        False   False          False
# 6887163                  False      False        False   False          False
# 6888711                  False      False        False   False          False
# 6934781                  False      False        False   False          False
#
#             f_WHEELCHAIR_ACCESS  f_COMMON_OUTDOOR_SPACE  interest_level
# listing_id
# 7211212                   False                   False               0
# 7150865                   False                   False              -1
# 6887163                   False                   False               1
# 6888711                   False                   False              -1
# 6934781                   False                   False              -1
#
# [5 rows x 31 columns]

# %% [markdown]
# - __bathrooms, features normalization__

# %%
norm_list = ['f_' + '_'.join(i.split(' ')) for i in add_ones] + ['bathrooms','Photo Number']
for i in norm_list:
    df[i] = preprocessing.scale(df[i])

# %%
df.head()
# Out:
#             bathrooms                       building_id  \
# listing_id
# 7211212      0.574016  53a5b119ba8f7b61d4e010512e0dfc85
# 7150865     -0.423163  c5c8a357cba207596b04d1afd1e4f130
# 6887163     -0.423163  c3ba40552e2120b0acfc3cb5730bb2aa
# 6888711     -0.423163  28d9ad350afeaab8027513a3e52ac8d5
# 6934781     -0.423163                                 0
#
#                                   manager_id  des_length  price/bedrooms  \
# listing_id
# 7211212     5ba989232d0489da1b5f2c45f6688adc   -0.035508       -0.116088
# 7150865     7533621a882f71e25173b27e3139d83d   -1.509129        0.020990
# 6887163     d9039c43983f6e564b1482b273bd7b01    0.226187       -0.029748
# 6888711     1067e078446a7897d2da493d2f741316   -0.279418       -0.002567
# 6934781     98e13ad4b495b9613cef886d79a6291f   -0.312447       -0.126321
#
#             Photo Number  f_ELEVATOR  f_HARDWOOD_FLOORS  f_CATS_ALLOWED  \
# listing_id
# 7211212        -0.167099   -1.066956          -0.955868       -0.954976
# 7150865         1.484771    0.937246          -0.955868        1.047147
# 6887163         0.658836   -1.066956           1.046169       -0.954976
# 6888711        -0.717723   -1.066956           1.046169       -0.954976
# 6934781        -0.717723   -1.066956          -0.955868       -0.954976
#
#             f_DOGS_ALLOWED  ...  f_BALCONY  f_SWIMMING_POOL  \
# listing_id                  ...
# 7211212          -0.898132  ...  -0.257372        -0.242359
# 7150865           1.113422  ...  -0.257372        -0.242359
# 6887163          -0.898132  ...  -0.257372        -0.242359
# 6888711          -0.898132  ...  -0.257372        -0.242359
# 6934781          -0.898132  ...  -0.257372        -0.242359
#
#             f_NEW_CONSTRUCTION  f_TERRACE  f_EXCLUSIVE    f_LOFT  \
# listing_id
# 7211212              -0.236206  -0.225196    -0.214406 -0.211128
# 7150865              -0.236206  -0.225196    -0.214406 -0.211128
# 6887163              -0.236206  -0.225196    -0.214406 -0.211128
# 6888711              -0.236206  -0.225196    -0.214406 -0.211128
# 6934781              -0.236206  -0.225196    -0.214406 -0.211128
#
#             f_GARDENPATIO  f_WHEELCHAIR_ACCESS  f_COMMON_OUTDOOR_SPACE  \
# listing_id
# 7211212         -0.202445            -0.168212               -0.164026
# 7150865         -0.202445            -0.168212               -0.164026
# 6887163         -0.202445            -0.168212               -0.164026
# 6888711         -0.202445            -0.168212               -0.164026
# 6934781         -0.202445            -0.168212               -0.164026
#
#             interest_level
# listing_id
# 7211212                  0
# 7150865                 -1
# 6887163                  1
# 6888711                 -1
# 6934781                 -1
#
# [5 rows x 31 columns]

# %% [markdown]
# - __manager expected level, building expected level（after train test split）__

# %%
# Add manager_level to train and test data
# Note that 'interest_level' must be included in x_train and x_test
# 'interest_level' will be dropped after this function being executed

#     manager = x_train.loc[:, {'manager_id', 'interest_level'}]
#     gb_m = x_train.groupby(manager['manager_id'])
#     manager_dic = {}
#     for m_id in gb.groups.keys():
#         level = gb.get_group(m_id)['interest_level']
#         manager_dic[m_id] = (sum(level)/len(level))
        
#     manager_level = []
#     for m_id in x_train['manager_id']:
#         manager_level.append(manager_dic[m_id])

#     x_train['manager_level'] = manager_level

#     manager_level = []
#     for m_id in x_test['manager_id']:
#         if m_id in manager_dic.keys():
#             manager_level.append(manager_dic[m_id])
#         else:
#             manager_level.append(-1)
#     x_test['manager_level'] = manager_level

def manager_building_level(x_train, x_test):    
    
    gb_m = x_train.groupby(x_train['manager_id'])
    m_dic = {m_id : np.mean(gb_m.get_group(m_id)['interest_level']) for m_id in gb_m.groups.keys()}
    x_train['manager_level'] = [m_dic[i] for i in x_train['manager_id']]
    x_test['manager_level'] = [m_dic[i] if i in gb_m.groups.keys() else np.mean(x_train['interest_level']) for i in x_test['manager_id']]
    
    
    gb_b = x_train.groupby(x_train['building_id'])
    b_dic = {b_id : np.mean(gb_b.get_group(b_id)['interest_level']) for b_id in gb_b.groups.keys()}
    x_train['building_level'] = [b_dic[i] for i in x_train['building_id']]
    x_test['building_level'] = [b_dic[i] if i in gb_b.groups.keys() else np.mean(x_train['interest_level']) for i in x_test['building_id']]
    
    
    x_train = x_train.drop({'manager_id', 'interest_level','building_id'}, 1)
    x_test = x_test.drop({'manager_id', 'interest_level','building_id'}, 1)

    
    return x_train, x_test

# %% [markdown]
# - __Train Test Split__

# %%
from sklearn.model_selection import train_test_split
x = df
y = df['interest_level']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33)

x_train, x_test = manager_building_level(x_train, x_test) 
x_train.head()
# Out:
#             bathrooms  des_length  price/bedrooms  Photo Number  f_ELEVATOR  \
# listing_id
# 7011164     -0.423163   -1.509129       -0.052132     -1.543658   -1.066956
# 6916294     -0.423163   -1.529455        0.043162     -1.543658   -1.066956
# 6858059     -0.423163    0.302408       -0.086242      0.108212    0.937246
# 7103522     -0.423163   -0.851081       -0.100259      0.658836   -1.066956
# 7039463     -0.423163    0.787687       -0.013919      0.383524   -1.066956
#
#             f_HARDWOOD_FLOORS  f_CATS_ALLOWED  f_DOGS_ALLOWED  f_DOORMAN  \
# listing_id
# 7011164             -0.955868       -0.954976       -0.898132  -0.861953
# 6916294             -0.955868        1.047147        1.113422  -0.861953
# 6858059              1.046169        1.047147        1.113422   1.160156
# 7103522             -0.955868       -0.954976       -0.898132  -0.861953
# 7039463              1.046169       -0.954976       -0.898132  -0.861953
#
#             f_DISHWASHER  ...  f_SWIMMING_POOL  f_NEW_CONSTRUCTION  f_TERRACE  \
# listing_id                ...
# 7011164        -0.854442  ...        -0.242359           -0.236206  -0.225196
# 6916294        -0.854442  ...        -0.242359           -0.236206  -0.225196
# 6858059         1.170355  ...        -0.242359           -0.236206  -0.225196
# 7103522        -0.854442  ...        -0.242359           -0.236206  -0.225196
# 7039463         1.170355  ...        -0.242359           -0.236206  -0.225196
#
#             f_EXCLUSIVE    f_LOFT  f_GARDENPATIO  f_WHEELCHAIR_ACCESS  \
# listing_id
# 7011164       -0.214406 -0.211128      -0.202445            -0.168212
# 6916294        4.664048 -0.211128      -0.202445            -0.168212
# 6858059       -0.214406 -0.211128      -0.202445            -0.168212
# 7103522       -0.214406 -0.211128      -0.202445            -0.168212
# 7039463       -0.214406 -0.211128      -0.202445            -0.168212
#
#             f_COMMON_OUTDOOR_SPACE  manager_level  building_level
# listing_id
# 7011164                  -0.164026      -0.986063       -0.666667
# 6916294                  -0.164026      -0.730435       -1.000000
# 6858059                  -0.164026      -0.602941       -0.545455
# 7103522                  -0.164026      -0.812500       -0.428571
# 7039463                  -0.164026      -0.636364       -0.893050
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Model Selection

# %%
#Model
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

#Evaluation
from sklearn.metrics import accuracy_score
from sklearn.metrics import log_loss
from sklearn.metrics import auc
from sklearn import metrics
from sklearn.model_selection import KFold

# %% [markdown]
# ### Linear Regression

# %%
# LR = LogisticRegression().fit(x_train, y_train)
# pred_proba_LR = LR.predict_proba(x_test)
# preds_LR = LR.predict(x_test)
# accuracy_score(y_test, preds_LR)

# %%
parameters = [100, 1]
scores = []
c_range = [0.0001, 0.001, 0.0025, 0.005, 0.01, 0.05, 0.1, 1]
for c in c_range:
    kf = KFold(n_splits = 3, shuffle = True)
    score = []
    for train_index, test_index in kf.split(x):
        x_train, x_test = x.iloc[train_index, :], x.iloc[test_index, :]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        x_train, x_test = manager_building_level(x_train, x_test)
            
        lr = LogisticRegression(C = c, multi_class='multinomial', solver='lbfgs').fit(x_train, y_train)
        pred_proba = lr.predict_proba(x_test)
        score.append(log_loss(y_test, pred_proba))
        
    mean_score = sum(score)/len(score)
    scores.append(mean_score)
    if mean_score < parameters[0]:
        parameters = [mean_score, c]

# %%
plt.plot(np.arange(8), scores)
plt.xticks(np.arange(8), c_range)
plt.xlabel("C")
plt.ylabel("Log loss")
plt.title("Tuning the Regularization for Logistic Regression")
plt.annotate('Best C=0.0025',xy=(2,parameters[0]), xytext=(2.5,0.677),
             arrowprops=dict(facecolor='red'))
plt.show()

# %% [markdown]
# ### K Nearest Neighbor(KNN) Classifier

# %%
# KNN = KNeighborsClassifier().fit(x_train, y_train)
# pred_proba_KNN = KNN.predict_proba(x_test)
# pred_KNN = KNN.predict(x_test)
# # accuracy_score(y_test, preds_KNN)
# for i in [-1,0,1]:
#     print(sum(pred_KNN == i)/len(pred_KNN))

# %%
# result_ac = pd.DataFrame(np.zeros((6,7)))
# result_ac.index = ['euclidean','manhattan','minkowski','euclidean_w','manhattan_w','minkowski_w']
# result_ac.columns = [5,10,20,30,50,75,100]

# %%
result_log = pd.DataFrame(np.zeros((6,8)))
result_log.index = ['euclidean','manhattan','minkowski','euclidean_w','manhattan_w','minkowski_w']
result_log.columns = [5, 10, 20, 30, 50, 70, 100, 130]

# %%
fig = plt.figure(figsize = (10, 8))
for i in [5, 10, 20, 30, 50, 70, 100, 130]:
    print(i)
    for w in ['euclidean','manhattan','minkowski']:
        
        kf = KFold(n_splits = 3, shuffle = True)
        score = []
        score_w = []
        for train_index, test_index in kf.split(x):
            x_train, x_test = x.iloc[train_index, :], x.iloc[test_index, :]
            y_train, y_test = y.iloc[train_index], y.iloc[test_index]

            x_train, x_test = manager_building_level(x_train, x_test)

            KNN = KNeighborsClassifier(n_neighbors  = i, weights = 'uniform', metric = w).fit(x_train, y_train)
            KNN_w = KNeighborsClassifier(n_neighbors  = i, weights = 'distance', metric = w).fit(x_train, y_train)
            pred_proba_KNN = KNN.predict_proba(x_test)
            pred_proba_KNN_w = KNN_w.predict_proba(x_test)
            
            score.append(log_loss(y_test, pred_proba_KNN))
            score_w.append(log_loss(y_test, pred_proba_KNN_w))

            mean_score = sum(score)/len(score)
            mean_score_w = sum(score_w)/len(score_w)
            
            result_log.loc[w,i] = mean_score
            result_log.loc[w+'_w',i] = mean_score_w
        
#         KNN = KNeighborsClassifier(n_neighbors  = i, weights = 'uniform', metric = w).fit(x_train, y_train)
#         KNN_w = KNeighborsClassifier(n_neighbors  = i, weights = 'distance', metric = w).fit(x_train, y_train)
#         pred_proba_KNN = KNN.predict_proba(x_test)
#         pred_proba_KNN_w = KNN_w.predict_proba(x_test)
#         pred_KNN = KNN.predict(x_test)
#         pred_KNN_w = KNN_w.predict(x_test)
        
        '''Accuracy'''
#         ac = accuracy_score(y_test, pred_KNN)
#         result_ac.loc[w,i] = ac
#         ac_w = accuracy_score(y_test, pred_KNN_w)
#         result_ac.loc[w+'_w',i] = ac_w

        '''Log Loss'''
#         log = log_loss(y_test, pred_proba_KNN)
#         result_log.loc[w,i] = log
#         log_w = log_loss(y_test, pred_proba_KNN_w)
#         result_log.loc[w+'_w',i] = log_w
        
        '''AUC'''
#         test_yscore = pd.DataFrame(pred_proba_KNN)[0]
#         fpr, tpr, thresholds = metrics.roc_curve(y_test, test_yscore, pos_label=-1)

#         test_yscore_w = pd.DataFrame(pred_proba_KNN_w)[0]
#         fpr_w, tpr_w, thresholds_w = metrics.roc_curve(y_test, test_yscore_w, pos_label=-1)

        
#         roc_auc = auc(fpr, tpr)
#         # if roc_auc < 0.5:
#         #     fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_yscore, pos_label = 2)
#         #     roc_auc = auc(fpr, tpr)
#         plt.plot(fpr, tpr, label='ROC curve (area = '+ str(format(roc_auc, '.3f')) +') of ' + w + ' when k = ' + str(i))

#         roc_auc_w = auc(fpr_w, tpr_w)
#         # if roc_auc < 0.5:
#         #     fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_yscore, pos_label = 2)
#         #     roc_auc = auc(fpr, tpr)
#         plt.plot(fpr_w, tpr_w, label='ROC curve (area = '+ str(format(roc_auc, '.3f')) +') of ' + w + '_w when k = ' + str(i))
        
#         print(w)
#     print(i)
    
# plt.plot([0, 1], [0, 1], 'k--')  # random predictions curve
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.0])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver Operating Characteristic')
# plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# Out:
# 5
# 10
# 20
# 30
# 50
# 70
# 100
# 130

# %%
# result_ac

# %%
result_log
# Out:
#                   5         10        20        30        50        70   \
# euclidean    3.740987  2.219535  1.393650  1.110472  0.870425  0.789341
# manhattan    3.714004  2.158239  1.372861  1.103496  0.885713  0.796803
# minkowski    3.704889  2.215129  1.388215  1.104758  0.875830  0.787377
# euclidean_w  4.486606  3.106079  2.302119  2.069097  1.859733  1.799991
# manhattan_w  4.483179  3.057847  2.332744  2.091229  1.888979  1.783226
# minkowski_w  4.461262  3.099907  2.360931  2.053301  1.898109  1.749408
#
#                   100       130
# euclidean    0.751209  0.725730
# manhattan    0.728163  0.708327
# minkowski    0.750804  0.727393
# euclidean_w  1.726592  1.664365
# manhattan_w  1.711367  1.667375
# minkowski_w  1.742941  1.735152

# %%
# import seaborn as sns
# sns.set(style="darkgrid")
# fig = plt.figure(figsize = (10, 8))
# for i in result_ac.index:
#     plt.plot([5,10,20,30,50,75,100], result_ac.loc[i,:], label = i)
# plt.legend()
# plt.title('Accuracy',fontdict = {'fontsize': 15})
# plt.xlabel('K')
# plt.ylabel('Accuracy')

# %%
fig = plt.figure(figsize = (10, 8))
for i in result_log.index:
    plt.plot([5, 10, 20, 30, 50, 70, 100, 130], result_log.loc[i,:], label = i)
plt.legend()
plt.title('Log Loss',fontdict = {'fontsize': 15})
plt.xlabel('K')
plt.ylabel('Log Loss')
# Out:
# Text(0, 0.5, 'Log Loss')

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# clf = RandomForestClassifier(n_estimators=1000)
# clf.fit(x_train, y_train)
# y_pred = clf.predict_proba(x_test)
# log_loss(y_test, y_pred)

# %%
n_estimators_ =  [200, 400, 600]
max_depth_ =  [7,8,9]
# criterion = ['gini', 'entropy']
min_samples_split_ = [100, 150, 200]
min_samples_leaf_ = [25, 50, 75]

# CV_rfc = GridSearchCV(estimator=clf, param_grid=param_grid, cv= 5)
# CV_rfc = GridSearchCV(estimator=clf, param_grid=param_grid)
# CV_rfc.fit(x_train, y_train)

# %%
result = []
fig = plt.figure(figsize = (10, 8))
for est in n_estimators_:
    print(est)
    for dep in max_depth_:
        for spl in min_samples_split_:
            for lea in min_samples_leaf_:
                
                kf = KFold(n_splits = 3, shuffle = True)
                score = []
                for train_index, test_index in kf.split(x):
                    x_train, x_test = x.iloc[train_index, :], x.iloc[test_index, :]
                    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
                    x_train, x_test = manager_building_level(x_train, x_test)

                    RF = RandomForestClassifier(n_estimators=est, max_depth = dep, min_samples_split = spl, min_samples_leaf = lea, criterion = 'entropy').fit(x_train, y_train)
                    
                    pred_proba_RF = RF.predict_proba(x_test)
                    score.append(log_loss(y_test, pred_proba_RF))
                mean_score = sum(score)/len(score)
                result.append(mean_score)
                    
#                 RF = RandomForestClassifier(n_estimators=est, max_depth = dep, min_samples_split = spl, min_samples_leaf = lea, criterion = 'entropy').fit(x_train, y_train)
#                 pred_proba_RF = RF.predict_proba(x_test)


                '''Log Loss'''
#                 log = log_loss(y_test, pred_proba_RF)
#                 result.append(log)


                '''AUC'''
#                 test_yscore = pd.DataFrame(pred_proba_RF)[0]
#                 fpr, tpr, thresholds = metrics.roc_curve(y_test, test_yscore, pos_label=-1)

#                 roc_auc = auc(fpr, tpr)
#                 plt.plot(fpr, tpr, label='ROC curve (area = '+ str(format(roc_auc, '.3f')) +') when n = ' + str(est) +', depth = ' + str(dep) + ', split = ' + str(spl) + ', leaf = ' + str(lea) + '.' )


# plt.plot([0, 1], [0, 1], 'k--')  # random predictions curve
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.0])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver Operating Characteristic')
# plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# Out:
# 200
# 400
# 600

# %%
index = ['200_7','200_8','200_9','400_7','400_8','400_9','600_7','600_8','600_9']
columns = ['100_25','100_50','100_75','150_25','150_50','150_75','200_25','200_50','200_75']
aray_log = np.array(result).reshape(9,9)
df_log = pd.DataFrame(np.array(result).reshape(9,9))
df_log.index = index
df_log.columns = columns
df_log
# Out:
#          100_25    100_50    100_75    150_25    150_50    150_75    200_25  \
# 200_7  0.634543  0.636869  0.636863  0.637166  0.636581  0.638676  0.636835
# 200_8  0.630994  0.633167  0.633177  0.632521  0.633601  0.633729  0.634496
# 200_9  0.629176  0.632474  0.633237  0.629353  0.631943  0.631659  0.632070
# 400_7  0.634385  0.637896  0.635683  0.638140  0.636446  0.634665  0.635035
# 400_8  0.632711  0.632807  0.632220  0.631223  0.633064  0.632312  0.633307
# 400_9  0.630839  0.631032  0.632350  0.629247  0.630215  0.634117  0.631494
# 600_7  0.635314  0.636616  0.634394  0.633328  0.635714  0.636365  0.635209
# 600_8  0.630219  0.633942  0.632839  0.632904  0.633270  0.634460  0.632165
# 600_9  0.629802  0.631849  0.632452  0.630784  0.629948  0.633709  0.632050
#
#          200_50    200_75
# 200_7  0.637098  0.634201
# 200_8  0.634468  0.634904
# 200_9  0.631974  0.631586
# 400_7  0.636227  0.636521
# 400_8  0.633154  0.634213
# 400_9  0.632894  0.632786
# 600_7  0.636995  0.637349
# 600_8  0.632877  0.633446
# 600_9  0.628748  0.632905

# %%
fig = plt.figure(figsize=(20,10))
ax1 = plt.subplot(121)
im1 = ax1.imshow(aray_log)
cbar = ax1.figure.colorbar(im1, ax=ax1)
ax1.set_xticks(np.arange(9))
ax1.set_yticks(np.arange(9))
ax1.set_xticklabels(['100_25','100_50','100_75','150_25','150_50','150_75','200_25','200_50','200_75'], fontsize=9)
ax1.set_yticklabels(['200_7','200_8','200_9','400_7','400_8','400_9','600_7','600_8','600_9'], fontsize=13)
for i in range(9):
    for j in range(9):
        text = ax1.text(j, i, round(aray_log[i][j], 4), ha="center", va="center", color="w")
ax1.set_xlabel('min_split/min_leaf', fontsize=16)
ax1.set_ylabel('n_estimaters/max depth', fontsize=16)
ax1.set_title('Log Loss for Random Forest Grid Search', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Log Loss for Random Forest Grid Search')

# %%
x = df
y = df['interest_level']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33)

x_train, x_test = manager_building_level(x_train, x_test) 
x_train.head()

lr = LogisticRegression(C = 0.0025, multi_class='multinomial', solver='lbfgs')
lr.fit(x_train, y_train)
preds = lr.predict_proba(x_test)
print('log_loss of LR (test): %.4f' % log_loss(y_test, preds))
preds_train = lr.predict_proba(x_train)
print('log_loss of LR (train): %.4f' % log_loss(y_train, preds_train))
print()

rf = RandomForestClassifier(n_estimators=400,max_depth=9, min_samples_split=100,min_samples_leaf=25,criterion='entropy')
rf.fit(x_train, y_train)
preds = rf.predict_proba(x_test)
print('log_loss of RF (test): %.4f' % log_loss(y_test, preds))
preds_train = rf.predict_proba(x_train)
print('log_loss of RF (train): %.4f' % log_loss(y_train, preds_train))
print()

knn = KNeighborsClassifier(n_neighbors  = 130, metric = 'manhattan')
knn.fit(x_train, y_train)
preds = knn.predict_proba(x_test)
print('log_loss of kNN (test): %.4f' % log_loss(y_test, preds))
preds_train = knn.predict_proba(x_train)
print('log_loss of kNN (train): %.4f' % log_loss(y_train, preds_train))
# Out:
# log_loss of LR (test): 0.6554
# log_loss of LR (train): 0.5228
#
# log_loss of RF (test): 0.6324
# log_loss of RF (train): 0.4911
#
# log_loss of kNN (test): 0.7079
# log_loss of kNN (train): 0.5877

# %% [markdown]
# ## Graphs at Data Cleaning

# %%
fig = plt.figure(figsize = (8, 6))
    
low = sum(df_original['interest_level'] == 'low')
medium = sum(df_original['interest_level'] == 'medium')
high = sum(df_original['interest_level'] == 'high')
count = [low, medium, high]
bars = plt.bar( [1,2,3],count, width = 0.4)
a = 0
for bar in bars:
    num = count[a]/(sum(count))
    plt.gca().text(bar.get_x() + bar.get_width()/2, bar.get_height() -1500, str(format(num*100,'.2f')) + '%', 
             ha='center', color='w', fontsize=13)
    a += 1
plt.xticks([1,2,3], ['Low','Medium','High'], fontsize = 13)
plt.title('Distribution of Target Variable', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Distribution of Target Variable')

# %%
fig = plt.figure(figsize = (10, 8))

df_original['created'] = pd.to_datetime(df_original['created'], format = '%Y-%m-%d %H:%M:%S')

barwidth = 0.3
for i in [4,5,6]:
    
    low = sum(df_original[df_original['created'].dt.month == i]['interest_level'] == 'low')
    medium = sum(df_original[df_original['created'].dt.month == i]['interest_level'] == 'medium')
    high = sum(df_original[df_original['created'].dt.month == i]['interest_level'] == 'high')
    count = [low,medium,high]
    bars = plt.bar([w + (i-5)*barwidth for w in [1,2,3]],count,width = barwidth, label = '2016.'+str(i))
    a = 0
    for bar in bars:
        num = count[a]/(sum(count))
        plt.gca().text(bar.get_x() + bar.get_width()/2, bar.get_height() - 400, str(format(num*100,'.2f')) + '%', 
                 ha='center', color='w', fontsize=12)
        a += 1
    
    
plt.xticks([1,2,3], ['Low','Medium','High'])
plt.legend()
plt.title('Distribution by Created Time', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Distribution by Created Time')

# %%
def lat_long(l):
    '''For latitude and longtitude, delete outlier and normalize.'''
    l = l.loc[l['latitude']<40.95, :]
    l = l.loc[l['latitude']>40.55, :]
    l = l.loc[l['longitude']<-73.80, :]
    l = l.loc[l['longitude']>-74.05, :]
    l['latitude'] = preprocessing.scale(l['latitude'])
    l['longitude'] = preprocessing.scale(l['longitude'])
    return l

df_original = lat_long(df_original)

high = df_original.loc[df_original['interest_level']=='high', :]
medium = df_original.loc[df_original['interest_level']=='medium', :]
low = df_original.loc[df_original['interest_level']=='low', :]

plt.figure(figsize=(17,3.5))

plt.subplot(131)
plt.scatter(high['longitude'], high['latitude'], 5, c='blue', label='high')
plt.title('high')

plt.subplot(132)
plt.scatter(medium['longitude'], medium['latitude'], 5, c='red', label='medium')
plt.title('medium')

plt.subplot(133)
plt.scatter(low['longitude'], low['latitude'], 5, c='orange', label='low')
plt.title('low')

plt.show()

# %%
df_original['Features List'] = df_original['features'].apply(lambda y : list(map(lambda x: x.upper().translate(table), y)))
df_original['Features String'] = df_original['Features List'].apply(' '.join)
biglist = ' '.join(df_original['Features String'])

from wordcloud import WordCloud

wordcloud = WordCloud( background_color='white',collocations=True).generate(biglist)
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('Key Words in Features', fontsize=16, y=1.05)
plt.show()
